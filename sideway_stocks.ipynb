# %%
import tushare as ts

# %%
# extract the 
id2name = {}
name2id = {}
stock_ids = []
stocks = ts.get_stock_basics()
for index, row in stocks.iterrows():
    stock_ids.append(index)
    name2id[row["name"]] = index
    id2name[index] = row["name"]

# %%
for i in range(10):
    print(stock_ids[i], id2name[stock_ids[i]])
# Out:
# 002927 N泰永
# 600193 创兴资源
# 600354 敦煌种业
# 300140 中环装备
# 600903 贵州燃气
# 300041 回天新材
# 002645 华宏科技
# 603616 韩建河山
# 300612 宣亚国际
# 600198 大唐电信

# %%
name2id["工商银行"]
# Out:
# '601398'

# %%
ts.get_hist_data("601398")
# Out:
#             open  high  close   low       volume  price_change  p_change  \
# date
# 2018-02-23  7.03  7.04   7.01  6.93   1895043.00          0.01      0.14
# 2018-02-22  7.03  7.08   7.00  6.96   2546631.00          0.12      1.74
# 2018-02-14  6.79  6.90   6.87  6.73   1805734.25          0.07      1.03
# 2018-02-13  6.66  6.88   6.81  6.64   4239094.50          0.20      3.03
# 2018-02-12  6.64  6.71   6.60  6.52   3544422.50         -0.08     -1.20
# 2018-02-09  6.58  6.72   6.67  6.43   6043811.50         -0.15     -2.20
# 2018-02-08  7.05  7.08   6.82  6.69   5409204.00         -0.31     -4.35
# 2018-02-07  7.57  7.67   7.12  7.00   6369817.50         -0.45     -5.95
# 2018-02-06  7.59  7.65   7.55  7.40   6795772.00         -0.20     -2.58
# 2018-02-05  7.48  7.77   7.75  7.46   4080189.75          0.15      1.97
# 2018-02-02  7.60  7.67   7.61  7.44   3322599.50         -0.07     -0.91
# 2018-02-01  7.44  7.70   7.68  7.42   4568140.00          0.20      2.67
# ...

# %%
def get_sideways_time():
    pass
